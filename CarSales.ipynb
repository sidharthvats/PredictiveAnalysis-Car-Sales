# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm
from matplotlib import pyplot as plt

# %% [markdown]
# ## Import File

# %%
data=pd.read_csv(r"C:\Users\sidha\Downloads\DATA FILES (Data Analysis)\Car Sales Project\Car_sales.csv")

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %% [markdown]
# ## Check Data Type

# %%
data.dtypes
# Out:
# Manufacturer               object
# Model                      object
# Sales_in_thousands        float64
# four_year_resale_value    float64
# Vehicle_type               object
# Price_in_thousands        float64
# Engine_size               float64
# Horsepower                float64
# Wheelbase                 float64
# Width                     float64
# Length                    float64
# Curb_weight               float64
# Fuel_capacity             float64
# Fuel_efficiency           float64
# Latest_Launch              object
# Power_perf_factor         float64
# dtype: object

# %% [markdown]
# ### Latest Launch is in object format

# %% [markdown]
# ## Rows and Columns

# %%
data.shape
# Out:
# (157, 16)

# %%
data.count()
# Out:
# Manufacturer              157
# Model                     157
# Sales_in_thousands        157
# four_year_resale_value    121
# Vehicle_type              157
# Price_in_thousands        155
# Engine_size               156
# Horsepower                156
# Wheelbase                 156
# Width                     156
# Length                    156
# Curb_weight               155
# Fuel_capacity             156
# Fuel_efficiency           154
# Latest_Launch             157
# Power_perf_factor         155
# dtype: int64

# %% [markdown]
# ## Duplicate Values

# %%
data.duplicated().value_counts()
# Out:
# False    157
# dtype: int64

# %% [markdown]
# ### NOT FOUND

# %% [markdown]
# ## Converting Latest_Launch into datetime

# %%
import datetime as dt

# %%
data.Latest_Launch = pd.to_datetime(data.Latest_Launch,format='%m/%d/%Y')

# %%
data.dtypes
# Out:
# Manufacturer                      object
# Model                             object
# Sales_in_thousands               float64
# four_year_resale_value           float64
# Vehicle_type                      object
# Price_in_thousands               float64
# Engine_size                      float64
# Horsepower                       float64
# Wheelbase                        float64
# Width                            float64
# Length                           float64
# Curb_weight                      float64
# Fuel_capacity                    float64
# Fuel_efficiency                  float64
# Latest_Launch             datetime64[ns]
# Power_perf_factor                float64
# dtype: object

# %%
td= dt.datetime.today()

# %%
td
# Out:
# datetime.datetime(2019, 8, 20, 1, 28, 11, 649087)

# %%
data.Latest_Launch = td-data.Latest_Launch

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# ...

# %%
data.dtypes
# Out:
# Manufacturer                       object
# Model                              object
# Sales_in_thousands                float64
# four_year_resale_value            float64
# Vehicle_type                       object
# Price_in_thousands                float64
# Engine_size                       float64
# Horsepower                        float64
# Wheelbase                         float64
# Width                             float64
# Length                            float64
# Curb_weight                       float64
# Fuel_capacity                     float64
# Fuel_efficiency                   float64
# Latest_Launch             timedelta64[ns]
# Power_perf_factor                 float64
# dtype: object

# %%
data.Latest_Launch=data.Latest_Launch.astype('str')

# %%
data.dtypes
# Out:
# Manufacturer               object
# Model                      object
# Sales_in_thousands        float64
# four_year_resale_value    float64
# Vehicle_type               object
# Price_in_thousands        float64
# Engine_size               float64
# Horsepower                float64
# Wheelbase                 float64
# Width                     float64
# Length                    float64
# Curb_weight               float64
# Fuel_capacity             float64
# Fuel_efficiency           float64
# Latest_Launch              object
# Power_perf_factor         float64
# dtype: object

# %%
data.Latest_Launch.head()
# Out:
# 0    2756 days 01:28:11.649087000
# 1    3000 days 01:28:11.649087000
# 2    2785 days 01:28:11.649087000
# 3    3085 days 01:28:11.649087000
# 4    2873 days 01:28:11.649087000
# Name: Latest_Launch, dtype: object

# %%
d=data.Latest_Launch

# %%
d.head()
# Out:
# 0    2756 days 01:28:11.649087000
# 1    3000 days 01:28:11.649087000
# 2    2785 days 01:28:11.649087000
# 3    3085 days 01:28:11.649087000
# 4    2873 days 01:28:11.649087000
# Name: Latest_Launch, dtype: object

# %%
days= data.Latest_Launch.str.replace(" days 01:28:11.649087000",'')

# %%
days.head()
# Out:
# 0    2756
# 1    3000
# 2    2785
# 3    3085
# 4    2873
# Name: Latest_Launch, dtype: object

# %%
days = days.astype('float')

# %%
data.Latest_Launch = days

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency  Latest_Launch  \
# ...

# %%
data.dtypes
# Out:
# Manufacturer               object
# Model                      object
# Sales_in_thousands        float64
# four_year_resale_value    float64
# Vehicle_type               object
# Price_in_thousands        float64
# Engine_size               float64
# Horsepower                float64
# Wheelbase                 float64
# Width                     float64
# Length                    float64
# Curb_weight               float64
# Fuel_capacity             float64
# Fuel_efficiency           float64
# Latest_Launch             float64
# Power_perf_factor         float64
# dtype: object

# %% [markdown]
# ## Variables

# %%
cat_vars = ['Manufacturer', 'Vehicle_type']
num_vars = ['Sales_in_thousands','Price_in_thousands',
            'Engine_size','Horsepower','Wheelbase','Width','Length','Curb_weight',
           'Fuel_capacity','Fuel_efficiency','Latest_Launch','Power_perf_factor']

# %%
data_cat=data[cat_vars]
data_num=data[num_vars]

# %%
data1 = pd.concat([data_cat,data_num],axis=1)

# %%
data1.head()
# Out:
#   Manufacturer Vehicle_type  Sales_in_thousands  Price_in_thousands  \
# 0        Acura    Passenger              16.919               21.50
# 1        Acura    Passenger              39.384               28.40
# 2        Acura    Passenger              14.114                 NaN
# 3        Acura    Passenger               8.588               42.00
# 4         Audi    Passenger              20.397               23.99
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  Fuel_efficiency  Latest_Launch  Power_perf_factor
# 0           13.2             28.0         2756.0          58.280150
# ...

# %% [markdown]
# ## Missing Value Treatment

# %%
data1.shape
# Out:
# (157, 14)

# %%
data1.count()
# Out:
# Manufacturer          157
# Vehicle_type          157
# Sales_in_thousands    157
# Price_in_thousands    155
# Engine_size           156
# Horsepower            156
# Wheelbase             156
# Width                 156
# Length                156
# Curb_weight           155
# Fuel_capacity         156
# Fuel_efficiency       154
# Latest_Launch         157
# Power_perf_factor     155
# dtype: int64

# %%
data1.head()
# Out:
#   Manufacturer Vehicle_type  Sales_in_thousands  Price_in_thousands  \
# 0        Acura    Passenger              16.919               21.50
# 1        Acura    Passenger              39.384               28.40
# 2        Acura    Passenger              14.114                 NaN
# 3        Acura    Passenger               8.588               42.00
# 4         Audi    Passenger              20.397               23.99
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  Fuel_efficiency  Latest_Launch  Power_perf_factor
# 0           13.2             28.0         2756.0          58.280150
# ...

# %%
q1=data_num.quantile(0.1)
q1
# Out:
# Sales_in_thousands       5.453600
# Price_in_thousands      13.970800
# Engine_size              1.950000
# Horsepower             120.000000
# Wheelbase               98.650000
# Width                   66.900000
# Length                 173.000000
# Curb_weight              2.606200
# Fuel_capacity           13.200000
# Fuel_efficiency         18.300000
# Latest_Launch         2510.000000
# Power_perf_factor       48.447741
# Name: 0.1, dtype: float64

# %%
q3=data_num.quantile(0.99)
q3
# Out:
# Sales_in_thousands     260.645320
# Price_in_thousands      78.479800
# Engine_size              5.700000
# Horsepower             325.750000
# Wheelbase              134.375000
# Width                   79.190000
# Length                 219.305000
# Curb_weight              5.396680
# Fuel_capacity           30.900000
# Fuel_efficiency         33.000000
# Latest_Launch         3591.000000
# Power_perf_factor      141.119461
# Name: 0.99, dtype: float64

# %%
def outlier_miss_treat(x):
    x = x.clip_upper(x.quantile(0.99))
    x = x.clip_lower(x.quantile(0.01))
    x = x.fillna(x.median())
    return x

# %%
data_num_new = data_num.apply(outlier_miss_treat)
# Out:
# C:\Users\sidha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: clip_upper(threshold) is deprecated, use clip(upper=threshold) instead
#
# C:\Users\sidha\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: clip_lower(threshold) is deprecated, use clip(lower=threshold) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def miss_treat_cat(x):
    x = x.fillna(x.mode())
    return x

# %%
data_cat_new = data_cat.apply(miss_treat_cat)

# %%
data_cat_new.head()
# Out:
#   Manufacturer Vehicle_type
# 0        Acura    Passenger
# 1        Acura    Passenger
# 2        Acura    Passenger
# 3        Acura    Passenger
# 4         Audi    Passenger

# %%
cat_dummies = pd.get_dummies(data_cat_new, drop_first=True)

# %%
cat_dummies.head()
# Out:
#    Manufacturer_Audi  Manufacturer_BMW  Manufacturer_Buick  \
# 0                  0                 0                   0
# 1                  0                 0                   0
# 2                  0                 0                   0
# 3                  0                 0                   0
# 4                  1                 0                   0
#
#    Manufacturer_Cadillac  Manufacturer_Chevrolet  Manufacturer_Chrysler  \
# 0                      0                       0                      0
# 1                      0                       0                      0
# 2                      0                       0                      0
# 3                      0                       0                      0
# 4                      0                       0                      0
#
#    Manufacturer_Dodge  Manufacturer_Ford  Manufacturer_Honda  \
# 0                   0                  0                   0
# ...

# %%
data_new = pd.concat([data_num_new, cat_dummies], axis=1)

# %%
data_new.head()
# Out:
#    Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0              16.919              21.500          1.8       140.0      101.2
# 1              39.384              28.400          3.2       225.0      108.1
# 2              14.114              22.799          3.2       225.0      106.9
# 3               8.588              42.000          3.5       210.0      114.6
# 4              20.397              23.990          1.8       150.0      102.6
#
#    Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  ...  \
# 0   67.3   172.4        2.639           13.2             28.0  ...
# 1   70.3   192.9        3.517           17.2             25.0  ...
# 2   70.6   192.0        3.470           17.2             26.0  ...
# 3   71.4   196.6        3.850           18.0             22.0  ...
# 4   68.2   178.0        2.998           16.4             27.0  ...
#
#    Manufacturer_Plymouth  Manufacturer_Pontiac  Manufacturer_Porsche  \
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
# Y Normality
h=np.log(data_new.Sales_in_thousands)
h.hist(bins=20)
plt.show()
data_new['lnSales']=h

# %%
sns.distplot(h)

# %%
data_new.head()
# Out:
#    Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0              16.919              21.500          1.8       140.0      101.2
# 1              39.384              28.400          3.2       225.0      108.1
# 2              14.114              22.799          3.2       225.0      106.9
# 3               8.588              42.000          3.5       210.0      114.6
# 4              20.397              23.990          1.8       150.0      102.6
#
#    Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  ...  \
# 0   67.3   172.4        2.639           13.2             28.0  ...
# 1   70.3   192.9        3.517           17.2             25.0  ...
# 2   70.6   192.0        3.470           17.2             26.0  ...
# 3   71.4   196.6        3.850           18.0             22.0  ...
# 4   68.2   178.0        2.998           16.4             27.0  ...
#
#    Manufacturer_Pontiac  Manufacturer_Porsche  Manufacturer_Saab  \
# ...

# %%
data_num_new.corrwith(data_num_new.Sales_in_thousands)
# Out:
# Sales_in_thousands    1.000000
# Price_in_thousands   -0.360085
# Engine_size          -0.014355
# Horsepower           -0.259332
# Wheelbase             0.278261
# Width                 0.092996
# Length                0.201007
# Curb_weight          -0.035062
# Fuel_capacity         0.044389
# Fuel_efficiency       0.036851
# Latest_Launch        -0.089921
# Power_perf_factor    -0.284396
# dtype: float64

# %%
corrm=data_new.corr()
corrm.to_csv('corrm.csv')
# visualize correlation matrix in Seaborn using a heatmap
sns.heatmap(data_new.corr())

# %%
data_new.head()
# Out:
#    Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0              16.919              21.500          1.8       140.0      101.2
# 1              39.384              28.400          3.2       225.0      108.1
# 2              14.114              22.799          3.2       225.0      106.9
# 3               8.588              42.000          3.5       210.0      114.6
# 4              20.397              23.990          1.8       150.0      102.6
#
#    Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  ...  \
# 0   67.3   172.4        2.639           13.2             28.0  ...
# 1   70.3   192.9        3.517           17.2             25.0  ...
# 2   70.6   192.0        3.470           17.2             26.0  ...
# 3   71.4   196.6        3.850           18.0             22.0  ...
# 4   68.2   178.0        2.998           16.4             27.0  ...
#
#    Manufacturer_Pontiac  Manufacturer_Porsche  Manufacturer_Saab  \
# ...

# %% [markdown]
# ## Feature Reduction

# %% [markdown]
# ## RF Elimination

# %%
features = features = data_new[data_new.columns.difference( ['lnSales', 'Sales_in_thousands	'] )]

# %%
features.head()
# Out:
#    Curb_weight  Engine_size  Fuel_capacity  Fuel_efficiency  Horsepower  \
# 0        2.639          1.8           13.2             28.0       140.0
# 1        3.517          3.2           17.2             25.0       225.0
# 2        3.470          3.2           17.2             26.0       225.0
# 3        3.850          3.5           18.0             22.0       210.0
# 4        2.998          1.8           16.4             27.0       150.0
#
#    Latest_Launch  Length  Manufacturer_Audi  Manufacturer_BMW  \
# 0         2756.0   172.4                  0                 0
# 1         3000.0   192.9                  0                 0
# 2         2785.0   192.0                  0                 0
# 3         3085.0   196.6                  0                 0
# 4         2873.0   178.0                  1                 0
#
#    Manufacturer_Buick  ...  Manufacturer_Subaru  Manufacturer_Toyota  \
# 0                   0  ...                    0                    0
# ...

# %%
target = target = data_new['lnSales']

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

import itertools

lm = LinearRegression()

# create the RFE model and select 10 attributes
rfe = RFE(lm, n_features_to_select=10)
rfe = rfe.fit(features, target)

# %%
RFE_features=features.columns[rfe.get_support()]

# %%
RFE_features
# Out:
# Index(['Manufacturer_Buick', 'Manufacturer_Chevrolet', 'Manufacturer_Ford',
#        'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Jeep',
#        'Manufacturer_Nissan', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
#        'Manufacturer_Toyota'],
#       dtype='object')

# %%
features1=features[RFE_features]

# %%
features1.head()
# Out:
#    Manufacturer_Buick  Manufacturer_Chevrolet  Manufacturer_Ford  \
# 0                   0                       0                  0
# 1                   0                       0                  0
# 2                   0                       0                  0
# 3                   0                       0                  0
# 4                   0                       0                  0
#
#    Manufacturer_Honda  Manufacturer_Hyundai  Manufacturer_Jeep  \
# 0                   0                     0                  0
# 1                   0                     0                  0
# 2                   0                     0                  0
# 3                   0                     0                  0
# 4                   0                     0                  0
#
#    Manufacturer_Nissan  Manufacturer_Pontiac  Manufacturer_Porsche  \
# 0                    0                     0                     0
# ...

# %%
a=list(features1.columns)

# %% [markdown]
# ## F Regression

# %%
from sklearn.feature_selection import f_regression
F_values, p_values  = f_regression(features, target )

# %%
import itertools
f_reg_results = [(i, v, z) for i, v, z in itertools.zip_longest(features.columns, F_values,  ['%.3f' % p for p in p_values])]

# %%
f_reg_results=pd.DataFrame(f_reg_results, columns=['Variable','F_Value', 'P_Value'])

# %%
f_reg_results
# Out:
#                    Variable     F_Value P_Value
# 0               Curb_weight    0.419364   0.518
# 1               Engine_size    2.309178   0.131
# 2             Fuel_capacity    0.063404   0.802
# 3           Fuel_efficiency    2.906072   0.090
# 4                Horsepower   29.701676   0.000
# 5             Latest_Launch    0.876344   0.351
# 6                    Length    6.965105   0.009
# 7         Manufacturer_Audi    2.874313   0.092
# 8          Manufacturer_BMW    0.726643   0.395
# 9        Manufacturer_Buick    1.196073   0.276
# 10    Manufacturer_Cadillac    0.887999   0.347
# 11   Manufacturer_Chevrolet    1.509316   0.221
# 12    Manufacturer_Chrysler    0.041308   0.839
# 13       Manufacturer_Dodge    1.207264   0.274
# 14        Manufacturer_Ford   21.061447   0.000
# 15       Manufacturer_Honda    3.852349   0.051
# 16     Manufacturer_Hyundai    0.409934   0.523
# 17    Manufacturer_Infiniti    0.012097   0.913
# 18      Manufacturer_Jaguar    0.201879   0.654
# ...

# %%
f_reg_results.sort_values(by=['P_Value'])
# Out:
#                    Variable     F_Value P_Value
# 14        Manufacturer_Ford   21.061447   0.000
# 36        Power_perf_factor   38.714619   0.000
# 37       Price_in_thousands   77.686951   0.000
# 4                Horsepower   29.701676   0.000
# 38       Sales_in_thousands  274.624992   0.000
# 40                Wheelbase   12.187805   0.001
# 29     Manufacturer_Porsche   10.653178   0.001
# 39   Vehicle_type_Passenger   12.462157   0.001
# 22  Manufacturer_Mercedes-B    9.878573   0.002
# 6                    Length    6.965105   0.009
# 35       Manufacturer_Volvo    3.934501   0.049
# 15       Manufacturer_Honda    3.852349   0.051
# 33      Manufacturer_Toyota    3.417935   0.066
# 27    Manufacturer_Plymouth    2.971046   0.087
# 3           Fuel_efficiency    2.906072   0.090
# 7         Manufacturer_Audi    2.874313   0.092
# 19        Manufacturer_Jeep    2.724204   0.101
# 20       Manufacturer_Lexus    2.648214   0.106
# 1               Engine_size    2.309178   0.131
# ...

# %%
f_reg_results.P_Value = pd.to_numeric(f_reg_results.P_Value)

# %%
f_reg_results=f_reg_results[f_reg_results.P_Value<=0.2]

# %%
f_reg_results
# Out:
#                    Variable     F_Value  P_Value
# 1               Engine_size    2.309178    0.131
# 3           Fuel_efficiency    2.906072    0.090
# 4                Horsepower   29.701676    0.000
# 6                    Length    6.965105    0.009
# 7         Manufacturer_Audi    2.874313    0.092
# 14        Manufacturer_Ford   21.061447    0.000
# 15       Manufacturer_Honda    3.852349    0.051
# 19        Manufacturer_Jeep    2.724204    0.101
# 20       Manufacturer_Lexus    2.648214    0.106
# 22  Manufacturer_Mercedes-B    9.878573    0.002
# 24  Manufacturer_Mitsubishi    1.764003    0.186
# 25      Manufacturer_Nissan    2.097272    0.150
# 27    Manufacturer_Plymouth    2.971046    0.087
# 29     Manufacturer_Porsche   10.653178    0.001
# 33      Manufacturer_Toyota    3.417935    0.066
# 35       Manufacturer_Volvo    3.934501    0.049
# 36        Power_perf_factor   38.714619    0.000
# 37       Price_in_thousands   77.686951    0.000
# ...

# %%
b= list(f_reg_results.Variable)

# %%
b
# Out:
# ['Engine_size',
#  'Fuel_efficiency',
#  'Horsepower',
#  'Length',
#  'Manufacturer_Audi',
#  'Manufacturer_Ford',
#  'Manufacturer_Honda',
#  'Manufacturer_Jeep',
#  'Manufacturer_Lexus',
#  'Manufacturer_Mercedes-B',
#  'Manufacturer_Mitsubishi',
#  'Manufacturer_Nissan',
#  'Manufacturer_Plymouth',
#  'Manufacturer_Porsche',
#  'Manufacturer_Toyota',
#  'Manufacturer_Volvo',
#  'Power_perf_factor',
#  'Price_in_thousands',
#  'Sales_in_thousands',
#  'Vehicle_type_Passenger',
#  'Wheelbase']

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices

# %%
x_new=data_new[['Sales_in_thousands', 'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
       'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor',
       'Manufacturer_Audi', 'Manufacturer_BMW', 'Manufacturer_Buick',
       'Manufacturer_Cadillac', 'Manufacturer_Chevrolet',
       'Manufacturer_Chrysler', 'Manufacturer_Dodge', 'Manufacturer_Ford',
       'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Infiniti',
       'Manufacturer_Jaguar', 'Manufacturer_Jeep', 'Manufacturer_Lexus',
       'Manufacturer_Lincoln', 'Manufacturer_Mercedes-B',
       'Manufacturer_Mercury', 'Manufacturer_Mitsubishi',
       'Manufacturer_Nissan', 'Manufacturer_Oldsmobile',
       'Manufacturer_Plymouth', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
       'Manufacturer_Saab', 'Manufacturer_Saturn', 'Manufacturer_Subaru',
       'Manufacturer_Toyota', 'Manufacturer_Volkswagen', 'Manufacturer_Volvo',
       'Vehicle_type_Passenger', 'lnSales']]

# %%
VIF = [variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]

# %%
VIF
# Out:
# [8.107003814528252,
#  161.46165094014913,
#  150.9576037044874,
#  2871.9118215438543,
#  1949.0778046791056,
#  1644.9528578956608,
#  2224.466100760222,
#  414.92055895411715,
#  170.84301340314707,
#  277.50907400707365,
#  223.16486051662272,
#  3977.561582354277,
#  2.1487478580602097,
#  2.023471761167964,
#  2.5067841986267134,
#  2.8033517609676815,
#  4.903709941488143,
#  3.6444154927917105,
#  5.927428058196976,
#  6.270288412585911,
#  3.115922466107976,
#  2.128182656473371,
#  1.3648347609029265,
#  1.4287060034157457,
#  2.530738227615073,
#  3.113581994411383,
#  2.326291107061728,
#  4.617881203794027,
#  3.375948384767433,
#  3.4531083271215866,
#  3.5392891427915125,
#  3.200578004336951,
#  3.0580623980150117,
#  3.376389155738272,
#  3.0095727833789234,
#  1.7581211677623259,
#  3.0698443537295943,
#  1.7179963297854768,
#  4.5529507339958215,
#  3.236497846265271,
#  3.1035956929387107,
#  21.074734303839314,
#  46.46685653497209]

# %%
VIF_results = pd.concat([pd.Series(x_new.columns), pd.Series(VIF)],axis=1)
VIF_results.columns = ['Feature','VIF']
VIFx = VIF_results.sort_values('VIF',ascending=False)

# %%
VIFx = VIFx.reset_index()

# %%
VIFx
# Out:
#     index                  Feature          VIF
# 0      11        Power_perf_factor  3977.561582
# 1       3               Horsepower  2871.911822
# 2       6                   Length  2224.466101
# 3       4                Wheelbase  1949.077805
# 4       5                    Width  1644.952858
# 5       7              Curb_weight   414.920559
# 6       9          Fuel_efficiency   277.509074
# 7      10            Latest_Launch   223.164861
# 8       8            Fuel_capacity   170.843013
# 9       1       Price_in_thousands   161.461651
# 10      2              Engine_size   150.957604
# 11     42                  lnSales    46.466857
# 12     41   Vehicle_type_Passenger    21.074734
# 13      0       Sales_in_thousands     8.107004
# 14     19        Manufacturer_Ford     6.270288
# 15     18       Manufacturer_Dodge     5.927428
# 16     16   Manufacturer_Chevrolet     4.903710
# 17     27  Manufacturer_Mercedes-B     4.617881
# 18     38      Manufacturer_Toyota     4.552951
# ...

# %%
list(VIFx.iloc[16:42,:].Feature)
# Out:
# ['Manufacturer_Chevrolet',
#  'Manufacturer_Mercedes-B',
#  'Manufacturer_Toyota',
#  'Manufacturer_Chrysler',
#  'Manufacturer_Nissan',
#  'Manufacturer_Mitsubishi',
#  'Manufacturer_Pontiac',
#  'Manufacturer_Mercury',
#  'Manufacturer_Volkswagen',
#  'Manufacturer_Oldsmobile',
#  'Manufacturer_Honda',
#  'Manufacturer_Lexus',
#  'Manufacturer_Volvo',
#  'Manufacturer_Saturn',
#  'Manufacturer_Plymouth',
#  'Manufacturer_Porsche',
#  'Manufacturer_Cadillac',
#  'Manufacturer_Jeep',
#  'Manufacturer_Buick',
#  'Manufacturer_Lincoln',
#  'Manufacturer_Audi',
#  'Manufacturer_Hyundai',
#  'Manufacturer_BMW',
#  'Manufacturer_Saab',
#  'Manufacturer_Subaru',
#  'Manufacturer_Jaguar']

# %% [markdown]
# ## Common Features

# %%
{'Manufacturer_Buick', 'Manufacturer_Chevrolet', 'Manufacturer_Ford',
       'Manufacturer_Honda', 'Manufacturer_Hyundai', 'Manufacturer_Jeep',
       'Manufacturer_Nissan', 'Manufacturer_Pontiac', 'Manufacturer_Porsche',
       'Manufacturer_Toyota','Engine_size',
 'Fuel_efficiency',
 'Horsepower',
 'Length',
 'Manufacturer_Audi',
 'Manufacturer_Ford',
 'Manufacturer_Honda',
 'Manufacturer_Jeep',
 'Manufacturer_Lexus',
 'Manufacturer_Mercedes-B',
 'Manufacturer_Mitsubishi',
 'Manufacturer_Nissan',
 'Manufacturer_Plymouth',
 'Manufacturer_Porsche',
 'Manufacturer_Toyota',
 'Manufacturer_Volvo',
 'Power_perf_factor',
 'Price_in_thousands',
 'Sales_in_thousands',
 'Vehicle_type_Passenger',
 'Wheelbase','Manufacturer_Chevrolet',
 'Manufacturer_Mercedes-B',
 'Manufacturer_Toyota',
 'Manufacturer_Chrysler',
 'Manufacturer_Nissan',
 'Manufacturer_Mitsubishi',
 'Manufacturer_Pontiac',
 'Manufacturer_Mercury',
 'Manufacturer_Volkswagen',
 'Manufacturer_Oldsmobile',
 'Manufacturer_Honda',
 'Manufacturer_Lexus',
 'Manufacturer_Volvo',
 'Manufacturer_Saturn',
 'Manufacturer_Plymouth',
 'Manufacturer_Porsche',
 'Manufacturer_Cadillac',
 'Manufacturer_Jeep',
 'Manufacturer_Buick',
 'Manufacturer_Lincoln',
 'Manufacturer_Audi',
 'Manufacturer_Hyundai',
 'Manufacturer_BMW',
 'Manufacturer_Saab',
 'Manufacturer_Subaru',
 'Manufacturer_Jaguar',
 'Power_perf_factor','Length','Horsepower','Wheelbase','Price_in_thousands'}
# Out:
# {'Engine_size',
#  'Fuel_efficiency',
#  'Horsepower',
#  'Length',
#  'Manufacturer_Audi',
#  'Manufacturer_BMW',
#  'Manufacturer_Buick',
#  'Manufacturer_Cadillac',
#  'Manufacturer_Chevrolet',
#  'Manufacturer_Chrysler',
#  'Manufacturer_Ford',
#  'Manufacturer_Honda',
#  'Manufacturer_Hyundai',
#  'Manufacturer_Jaguar',
#  'Manufacturer_Jeep',
#  'Manufacturer_Lexus',
#  'Manufacturer_Lincoln',
#  'Manufacturer_Mercedes-B',
#  'Manufacturer_Mercury',
#  'Manufacturer_Mitsubishi',
#  'Manufacturer_Nissan',
#  'Manufacturer_Oldsmobile',
#  'Manufacturer_Plymouth',
#  'Manufacturer_Pontiac',
#  'Manufacturer_Porsche',
#  'Manufacturer_Saab',
#  'Manufacturer_Saturn',
#  'Manufacturer_Subaru',
#  'Manufacturer_Toyota',
#  'Manufacturer_Volkswagen',
#  'Manufacturer_Volvo',
#  'Power_perf_factor',
#  'Price_in_thousands',
#  'Sales_in_thousands',
#  'Vehicle_type_Passenger',
#  'Wheelbase'}

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split( data_new, test_size = 0.3, random_state = 1234 )

print(len(train))
print(len(test))
# Out:
# 109
# 48

# %%
model=sm.ols('lnSales~Engine_size+Fuel_efficiency+Horsepower+Length+Manufacturer_Audi+Manufacturer_BMW+Manufacturer_Buick+Manufacturer_Cadillac+Manufacturer_Chevrolet+Manufacturer_Chrysler+Manufacturer_Ford+Manufacturer_Honda+Manufacturer_Hyundai+Manufacturer_Jaguar+Manufacturer_Jeep+Manufacturer_Lexus+Manufacturer_Lincoln+Manufacturer_Mercury+Manufacturer_Mitsubishi+Manufacturer_Nissan+Manufacturer_Oldsmobile+Manufacturer_Plymouth+Manufacturer_Pontiac+Manufacturer_Porsche+Manufacturer_Saab+Manufacturer_Saturn+Manufacturer_Subaru+Manufacturer_Toyota+Manufacturer_Volkswagen+Manufacturer_Volvo+Power_perf_factor+Price_in_thousands+Sales_in_thousands+Vehicle_type_Passenger+Wheelbase',data=train)

# %%
model=model.fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                lnSales   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     12.20
# Date:                Tue, 20 Aug 2019   Prob (F-statistic):           5.30e-19
# Time:                        01:31:27   Log-Likelihood:                -68.977
# No. Observations:                 109   AIC:                             208.0
# Df Residuals:                      74   BIC:                             302.2
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.4029      1.928     -0.209      0.835      -4.244       3.438
# ...
